# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
answer_1 = """
How can we prioritize SEO effort based on expected future organic performance?
"""

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
answer_2 = """
This project aims to improve the decision of which web pages should receive SEO effort first. The recommended action is to refresh, optimize, or maintain selected pages according to their predicted future organic performance. A wrong recommendation could waste limited SEO resources on low-impact pages while overlooking higher-opportunity pages, resulting in reduced future organic performance and less effective content optimization.
"""

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
answer_3 = """
The starter dataset contains 30,000 pages and 44 features describing content characteristics, search demand, user engagement, and historical organic performance. These observations suggest that the dataset is sufficiently rich to investigate SEO page prioritization, although further exploration is required to identify the most appropriate prediction target.
"""

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
answer_4 = """
At this stage, the research proposes using machine learning as a decision-support tool for prioritizing SEO effort. However, the appropriate prediction target has not yet been finalized. Further exploratory analysis is required to determine whether the existing dataset already provides a suitable observable outcome or whether a composite Organic Performance Score should be defined. Therefore, all conclusions in this framing are treated as hypotheses rather than established findings.
"""

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
